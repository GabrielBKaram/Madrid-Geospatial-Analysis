# %% [markdown]
# ## Define Task

# %% [markdown]
# Madrid, Spain's central capital, is a city of elegant boulevards, expansive parks and beautiful historical scenery. It's renowned for its rich repositories of European art, including the Prado Museum's works by Goya and Velazquez. It is also a region with a great variety of cuisines. Its central location and the many people originally from other regions of the country have influenced the cuisine of Madrid. The population size currently stands at 6.5 million inhabitants and the city also enjoys a large wave of tourists and international students moving to experience living in the Spanish capital.
#
# Restaurants are spread all over the city with a massive variation ranging from oriental to mediterranean and cuisines from different European countries. One can imagine that opening up a restaurant in Madrid is not going to very easy due to the high competition that there is. Many restaurants that open end up failing due to underplanning and lacking of a solid business strategy.
#
# I would like to open an Italian restaurant in Madrid but I want to make sure that it is indeed a good idea. The main business problem here would be whether the investment in opening an Italian restaurant will be profitable and worth the time, effort and money spent.
#
# In order to fully understand the market and whether to procceed with the investment or not, I will take a look at population data and venues data to see what are the most common venues in the city. I will also study where would be the ideal location to open the restaurant based on different factors.

# %% [markdown]
# ## Data Cleaning & Preparation

# %% [markdown]
# #### Import all packages that will be used for the analyis

# %%
#Import packages
import pandas as pd
import numpy as np
import requests
import json
from bs4 import BeautifulSoup
from sklearn.cluster import KMeans
import seaborn as sns
import matplotlib.pyplot as plt
from geopy.geocoders import Nominatim
import folium
from pandas.io.json import json_normalize
import matplotlib.cm as cm
import matplotlib.colors as colors

print("All libraries are imported.")
# Out:
# All libraries are imported.

# %% [markdown]
# #### Crawl wikipedia to get list of districts in Madrid and then merge coordinates data to create final dataset

# %%
#Extract districts of Madrid along with population and size
url = 'https://es.wikipedia.org/w/index.php?title=Anexo:Distritos_de_Madrid&oldid=119991001'
Madrid = requests.get(url)

#Use beautifulsoup to extract the table of interest from the page
soup = BeautifulSoup(Madrid.content, 'lxml')
Districts = soup.find_all('table')[0]
df = pd.read_html(url, flavor = 'bs4')
df = pd.read_json(df[0].to_json(orient = 'records'))

#Drop unnecessary columns and rows
df.drop(['Número','Imagen', 'Superficie[n. 1]​ (Ha.)'], axis = 1, inplace = True)
df.drop(df.tail(1).index, inplace = True)

#Change the title of the columns
df.columns = ['District', 'Population', 'Pop Density', 'Streets']

#Clean streets column from paranthesis
df['Streets'] = df['Streets'].str.replace(r"\((.*?)\)",", ", regex = True)

#Import dataset with coordinates and zip codes & merge it with current dataset
df1 = pd.read_csv('/Users/user/Desktop/Geospatial Coordinates Madrid.csv')
madrid_data = pd.merge(df, df1, on = 'District')

#Reorder columns
madrid_data = madrid_data[['Zip Code', 'District', 'Population', 'Pop Density', 'Streets', 'Latitude', 'Longitude']]

#Display data
madrid_data
# Out:
#     Zip Code             District Population  Pop Density  \
# 0      28013               Centro    131 928        25234
# 1      28005           Arganzuela    151 965        23516
# 2      28009               Retiro    118 516        21682
# 3      28001            Salamanca    143 800        26667
# 4      28036            Chamartín    143 424        15631
# 5      28013               Tetuán    153 789        28613
# 6      28015             Chamberí    137 401        29364
# 7      28004  Fuencarral-El Pardo    238 756         1004
# 8      28008      Moncloa-Aravaca    116 903         2512
# 9      28047               Latina    233 808         9195
# 10     28025          Carabanchel    243 998        17368
# 11     28026                Usera    134 791        17330
# 12     28038   Puente de Vallecas    227 595        15205
# 13     28030            Moratalaz     94 197        15434
# 14     28027        Ciudad Lineal    212 529        18601
# 15     28004            Hortaleza    180 462         6581
# 16     28021           Villaverde    142 608         7064
# 17     28031    Villa de Vallecas    104 421         1986
# 18     28028            Vicálvaro     70 051         1986
# 19     28022  San Blas-Canillejas    154 357         6924
# 20     28042              Barajas     46 876         1118
#
#                                               Streets  Latitude  Longitude
# 0   Palacio , Embajadores , Cortes , Justicia , Un...   40.4190    -3.7118
# 1   Imperial , Acacias , Chopera , Legazpi , Delic...   40.4050    -3.7105
# 2   Pacífico , Adelfas , Estrella , Ibiza , Jeróni...   40.4162    -3.6801
# 3   Recoletos , Goya , Fuente del Berro , Guindale...   40.4262    -3.6851
# 4   El Viso , Prosperidad , Ciudad Jardín , Hispan...   40.4618    -3.6851
# 5   Bellas Vistas , Cuatro Caminos , Castillejos ,...   40.4190    -3.7118
# 6   Gaztambide , Arapiles , Trafalgar , Almagro , ...   40.4305    -3.7105
# 7   El Pardo , Fuentelarreina , Peñagrande , Pilar...   40.4245    -3.6991
# 8   Casa de Campo , Argüelles , Ciudad Universitar...   40.4300    -3.7257
# 9   Los Cármenes , Puerta del Ángel , Lucero , Alu...   40.3961    -3.7486
# 10  Comillas , Opañel , San Isidro , Vista Alegre ...   40.3787    -3.7359
# 11  Orcasitas , Orcasur , San Fermín , Almendrales...   40.3848    -3.7054
# 12  Entrevías , San Diego , Palomeras Bajas , Palo...   40.3966    -3.6547
# 13  Pavones , Horcajo , Marroquina , Media Legua ,...   40.4073    -3.6395
# 14  Ventas , Pueblo Nuevo , Quintana , Concepción ...   40.4427    -3.6446
# 15  Palomas , Piovera , Canillas , Pinar del Rey ,...   40.4245    -3.6991
# 16  Villaverde Alto , San Cristóbal , Butarque , L...   40.3367    -3.6978
# 17  Casco Histórico de Vallecas , Santa Eugenia , ...   40.3809    -3.5863
# 18  Casco Histórico de Vicálvaro , Valdebernardo ,...   40.4319    -3.6649
# 19  Simancas , Hellín , Amposta , Arcos , Rosas , ...   40.4420    -3.5863
# 20  Alameda de Osuna , Aeropuerto , Casco Históric...   40.4679    -3.5711

# %% [markdown]
# The above information will be used to plot the map of Madrid based on the coordinates (longitude and latitude) in order to later check what are the most common venues in each district.

# %% [markdown]
# ## Madrid: Geospatial Analysis

# %% [markdown]
# ### A. Create a map and access the foursquare API

# %% [markdown]
# #### Create a map of Madrid

# %%
#Create an agent for the Madrid map and use geolocator
address = 'Madrid, Spain'
geolocator = Nominatim(user_agent = "mad_explorer")
location = geolocator.geocode(address)
Latitude = location.latitude
Longitude = location.longitude
print('The geograpical coordinates of Madrid are {}, {}.'.format(Latitude, Longitude))

#Create a map of Madrid using longitude and latitude values
map_madrid = folium.Map(location = [Latitude, Longitude], zoom_start = 11)

#Add markers on the map
for lat, lng, label in zip(madrid_data['Latitude'], madrid_data['Longitude'], madrid_data['District']):
    label = folium.Popup(label, parse_html = True)
    folium.CircleMarker(
        [lat, lng],
        radius = 5,
        popup = label,
        color = 'blue',
        fill = True,
        fill_color = '#3186cc',
        fill_opacity = 0.7,
        parse_html = False).add_to(map_madrid)  
    
#Display the map
map_madrid
# Out:
# The geograpical coordinates of Madrid are 40.4167047, -3.7035825.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Access Foursquare API to get venue details

# %% [markdown]
# I will use the foursquare API to be able to identify the venues that are located in every district. This is useful because then I will see what are the most common venues in each district which can help in identifying the ideal location to open the Italian restaurant.

# %%
#Access foursquare to get all the different venues in all different districts in Madrid
CLIENT_ID = 'TQT1M33FH3JO1HO2M0TPR1MPERDTRV0GTTWVM5WQ1DQEWYUN'
CLIENT_SECRET = '5SJJCS23XPAKSKMR2WGIB1D3W4YQEZB1MXFYBFVKYKP2ZFUB'
VERSION = '20180605'

print('My credentials for Foursquare are:')
print('CLIENT_ID:', CLIENT_ID)
print('CLIENT_SECRET:', CLIENT_SECRET)
# Out:
# My credentials for Foursquare are:
# CLIENT_ID: TQT1M33FH3JO1HO2M0TPR1MPERDTRV0GTTWVM5WQ1DQEWYUN
# CLIENT_SECRET: 5SJJCS23XPAKSKMR2WGIB1D3W4YQEZB1MXFYBFVKYKP2ZFUB

# %% [markdown]
# ### B. Explore the first neighborhood (Centro)

# %% [markdown]
# #### Get coordinates data of the centro district

# %%
#Lock dataset to display the first district/neighborhood (Centro)
madrid_data.loc[0, 'District']

#Get the longitude and latitude of the Centro district
centro_latitude = madrid_data.loc[0, 'Latitude']
centro_longitude = madrid_data.loc[0, 'Longitude']
centro = madrid_data.loc[0, 'District']

#Display the coordinates of the centro district
print('Latitude and longitude values of {} are {}, {}.'.format(centro, centro_latitude, centro_longitude))
# Out:
# Latitude and longitude values of Centro are 40.419000000000004, -3.7118.

# %% [markdown]
# #### Get information on venues in the centro district

# %%
#Get the top 100 venues in centro whithin a radius of 500m
LIMIT = 100
RADIUS = 500

#Create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    centro_latitude, 
    centro_longitude, 
    RADIUS, 
    LIMIT)
print(url)

#Get results
results = requests.get(url).json()
results

#Function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']
# Out:
# https://api.foursquare.com/v2/venues/explore?&client_id=TQT1M33FH3JO1HO2M0TPR1MPERDTRV0GTTWVM5WQ1DQEWYUN&client_secret=5SJJCS23XPAKSKMR2WGIB1D3W4YQEZB1MXFYBFVKYKP2ZFUB&v=20180605&ll=40.419000000000004,-3.7118&radius=500&limit=100

# %% [markdown]
# ### C. Explore all venues around all districts of Madrid

# %% [markdown]
# #### Build and clean venues in a new dataset

# %%
#Clean and structure dataset in pandas df
venues = results['response']['groups'][0]['items']
nearby_venues = json_normalize(venues) #flatten JSON

#Filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

#Filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis = 1)

#Clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

#Display dataset
nearby_venues.head()

#Print the number of venues returned by foursquare API
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 100 venues were returned by Foursquare.

# %% [markdown]
# #### Retrieve information on all venues located in Madrid

# %%
#Define function that gets information about all venues in Madrid
def getNearbyVenues(names, latitudes, longitudes, radius = 500):
    
    venues_list = []
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['District', 
                  'District Latitude', 
                  'District Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)


#Run above function and check output
madrid_venues = getNearbyVenues(names = madrid_data['District'],
                                   latitudes = madrid_data['Latitude'],
                                   longitudes = madrid_data['Longitude']
                                  )

#Check size of df created
print(madrid_venues.shape)
madrid_venues.head()
# Out:
# Centro
# Arganzuela
# Retiro
# Salamanca
# Chamartín
# Tetuán
# Chamberí
# Fuencarral-El Pardo
# Moncloa-Aravaca
# Latina
# Carabanchel
# Usera
# Puente de Vallecas
# Moratalaz
# Ciudad Lineal
# Hortaleza
# Villaverde
# Villa de Vallecas
# Vicálvaro
# San Blas-Canillejas
# Barajas
# (849, 7)
#   District  District Latitude  District Longitude  \
# 0   Centro             40.419             -3.7118
# 1   Centro             40.419             -3.7118
# 2   Centro             40.419             -3.7118
# 3   Centro             40.419             -3.7118
# 4   Centro             40.419             -3.7118
#
#                                     Venue  Venue Latitude  Venue Longitude  \
# 0                        Plaza de Oriente       40.418326        -3.712196
# 1                    Jardines de Sabatini       40.419954        -3.713126
# 2                   Teatro Real de Madrid       40.418226        -3.711064
# 3  Gran Meliá Palacio de los Duques *****       40.419835        -3.709494
# 4                              El Mollete       40.419913        -3.710503
#
#      Venue Category
# 0             Plaza
# 1            Garden
# 2       Opera House
# 3             Hotel
# 4  Tapas Restaurant

# %% [markdown]
# #### Check number of venues returned for each neighborhood

# %%
#Check how many venues returned for each neighborhood
madrid_venues.groupby('District').count()
# Out:
#                      District Latitude  District Longitude  Venue  \
# District
# Arganzuela                          28                  28     28
# Barajas                             40                  40     40
# Carabanchel                          3                   3      3
# Centro                             100                 100    100
# Chamartín                           40                  40     40
# Chamberí                            83                  83     83
# Ciudad Lineal                       13                  13     13
# Fuencarral-El Pardo                100                 100    100
# Hortaleza                          100                 100    100
# Latina                               8                   8      8
# Moncloa-Aravaca                     17                  17     17
# Moratalaz                           10                  10     10
# Puente de Vallecas                   9                   9      9
# Retiro                              37                  37     37
# Salamanca                          100                 100    100
# San Blas-Canillejas                 12                  12     12
# Tetuán                             100                 100    100
# Usera                               17                  17     17
# Vicálvaro                           29                  29     29
# Villaverde                           3                   3      3
#
#                      Venue Latitude  Venue Longitude  Venue Category
# District
# Arganzuela                       28               28              28
# Barajas                          40               40              40
# Carabanchel                       3                3               3
# Centro                          100              100             100
# Chamartín                        40               40              40
# Chamberí                         83               83              83
# Ciudad Lineal                    13               13              13
# Fuencarral-El Pardo             100              100             100
# Hortaleza                       100              100             100
# Latina                            8                8               8
# Moncloa-Aravaca                  17               17              17
# Moratalaz                        10               10              10
# Puente de Vallecas                9                9               9
# Retiro                           37               37              37
# Salamanca                       100              100             100
# San Blas-Canillejas              12               12              12
# Tetuán                          100              100             100
# Usera                            17               17              17
# Vicálvaro                        29               29              29
# Villaverde                        3                3               3

# %% [markdown]
# #### Check number of unique venue categories

# %%
#Check how many unique categories
print('There are {} uniques categories.'.format(len(madrid_venues['Venue Category'].unique())))
# Out:
# There are 148 uniques categories.

# %% [markdown]
# #### Dummy encode categorical variables to be able to use them

# %%
#One hot encoding to change format to numerical
madrid_onehot = pd.get_dummies(madrid_venues[['Venue Category']], prefix = "", prefix_sep = "")

#Add district column back to dataframe
madrid_onehot['District'] = madrid_venues['District'] 

#Move district column to make it as first column
fixed_columns = [madrid_onehot.columns[-1]] + list(madrid_onehot.columns[:-1])
madrid_onehot = madrid_onehot[fixed_columns]
madrid_onehot.head()

#Examine new shape after OHE
madrid_onehot.shape
# Out:
# (849, 149)

# %%
#Group rows by district by taking the mean of the frequency of occurence of each category
madrid_grouped = madrid_onehot.groupby('District').mean().reset_index()
madrid_grouped
# Out:
#                District  Accessories Store  Airport Gate  Airport Lounge  \
# 0            Arganzuela              0.000          0.00            0.00
# 1               Barajas              0.025          0.05            0.05
# 2           Carabanchel              0.000          0.00            0.00
# 3                Centro              0.000          0.00            0.00
# 4             Chamartín              0.000          0.00            0.00
# 5              Chamberí              0.000          0.00            0.00
# 6         Ciudad Lineal              0.000          0.00            0.00
# 7   Fuencarral-El Pardo              0.000          0.00            0.00
# 8             Hortaleza              0.000          0.00            0.00
# 9                Latina              0.000          0.00            0.00
# 10      Moncloa-Aravaca              0.000          0.00            0.00
# 11            Moratalaz              0.000          0.00            0.00
# 12   Puente de Vallecas              0.000          0.00            0.00
# 13               Retiro              0.000          0.00            0.00
# 14            Salamanca              0.030          0.00            0.00
# 15  San Blas-Canillejas              0.000          0.00            0.00
# 16               Tetuán              0.000          0.00            0.00
# 17                Usera              0.000          0.00            0.00
# 18            Vicálvaro              0.000          0.00            0.00
# 19           Villaverde              0.000          0.00            0.00
#
#     Airport Service  Airport Terminal  American Restaurant  \
# 0               0.0               0.0                0.000
# 1               0.1               0.1                0.000
# 2               0.0               0.0                0.000
# 3               0.0               0.0                0.010
# 4               0.0               0.0                0.025
# 5               0.0               0.0                0.000
# 6               0.0               0.0                0.000
# 7               0.0               0.0                0.030
# 8               0.0               0.0                0.030
# 9               0.0               0.0                0.000
# 10              0.0               0.0                0.000
# 11              0.0               0.0                0.000
# 12              0.0               0.0                0.000
# 13              0.0               0.0                0.000
# 14              0.0               0.0                0.020
# 15              0.0               0.0                0.000
# 16              0.0               0.0                0.010
# 17              0.0               0.0                0.000
# 18              0.0               0.0                0.000
# 19              0.0               0.0                0.000
#
#     Argentinian Restaurant  Art Gallery  Art Museum  ...  Taco Place  \
# 0                 0.000000     0.071429    0.000000  ...    0.000000
# 1                 0.000000     0.000000    0.000000  ...    0.000000
# 2                 0.000000     0.000000    0.000000  ...    0.000000
# 3                 0.020000     0.000000    0.000000  ...    0.000000
# 4                 0.025000     0.000000    0.000000  ...    0.000000
# 5                 0.000000     0.000000    0.012048  ...    0.012048
# 6                 0.000000     0.000000    0.000000  ...    0.000000
# 7                 0.010000     0.000000    0.000000  ...    0.000000
# 8                 0.010000     0.000000    0.000000  ...    0.000000
# 9                 0.000000     0.000000    0.000000  ...    0.000000
# 10                0.058824     0.000000    0.000000  ...    0.000000
# 11                0.000000     0.000000    0.000000  ...    0.000000
# 12                0.000000     0.000000    0.000000  ...    0.000000
# 13                0.027027     0.000000    0.027027  ...    0.000000
# 14                0.000000     0.000000    0.000000  ...    0.000000
# 15                0.000000     0.000000    0.000000  ...    0.000000
# 16                0.020000     0.000000    0.000000  ...    0.000000
# 17                0.000000     0.000000    0.000000  ...    0.000000
# 18                0.000000     0.000000    0.000000  ...    0.000000
# 19                0.000000     0.000000    0.000000  ...    0.000000
#
#     Tapas Restaurant  Thai Restaurant   Theater  Thrift / Vintage Store  \
# 0           0.107143             0.00  0.000000                    0.00
# 1           0.000000             0.00  0.000000                    0.00
# 2           0.000000             0.00  0.000000                    0.00
# 3           0.030000             0.00  0.020000                    0.00
# 4           0.000000             0.00  0.000000                    0.00
# 5           0.036145             0.00  0.036145                    0.00
# 6           0.153846             0.00  0.000000                    0.00
# 7           0.050000             0.01  0.000000                    0.00
# 8           0.050000             0.01  0.000000                    0.00
# 9           0.000000             0.00  0.000000                    0.00
# 10          0.117647             0.00  0.000000                    0.00
# 11          0.000000             0.00  0.000000                    0.00
# 12          0.000000             0.00  0.000000                    0.00
# 13          0.027027             0.00  0.000000                    0.00
# 14          0.040000             0.00  0.000000                    0.01
# 15          0.000000             0.00  0.000000                    0.00
# 16          0.030000             0.00  0.020000                    0.00
# 17          0.000000             0.00  0.000000                    0.00
# 18          0.000000             0.00  0.034483                    0.00
# 19          0.000000             0.00  0.000000                    0.00
#
#     Train Station  Vegetarian / Vegan Restaurant  Wine Bar  Wine Shop  \
# 0           0.000                       0.000000      0.00       0.00
# 1           0.000                       0.000000      0.00       0.00
# 2           0.000                       0.000000      0.00       0.00
# 3           0.000                       0.000000      0.02       0.01
# 4           0.000                       0.000000      0.00       0.00
# 5           0.000                       0.000000      0.00       0.00
# 6           0.000                       0.000000      0.00       0.00
# 7           0.000                       0.010000      0.01       0.00
# 8           0.000                       0.010000      0.01       0.00
# 9           0.125                       0.000000      0.00       0.00
# 10          0.000                       0.000000      0.00       0.00
# 11          0.000                       0.000000      0.00       0.00
# 12          0.000                       0.000000      0.00       0.00
# 13          0.000                       0.027027      0.00       0.00
# 14          0.000                       0.000000      0.00       0.00
# 15          0.000                       0.000000      0.00       0.00
# 16          0.000                       0.000000      0.02       0.01
# 17          0.000                       0.000000      0.00       0.00
# 18          0.000                       0.000000      0.00       0.00
# 19          0.000                       0.000000      0.00       0.00
#
#     Yoga Studio
# 0          0.00
# 1          0.00
# 2          0.00
# 3          0.00
# 4          0.00
# 5          0.00
# 6          0.00
# 7          0.01
# 8          0.01
# 9          0.00
# 10         0.00
# 11         0.00
# 12         0.00
# 13         0.00
# 14         0.00
# 15         0.00
# 16         0.00
# 17         0.00
# 18         0.00
# 19         0.00
#
# [20 rows x 149 columns]

# %%
#Print each district along with top 5 most common venues
num_top_venues = 5

for hood in madrid_grouped['District']:
    print("----"+hood+"----")
    temp = madrid_grouped[madrid_grouped['District'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending = False).reset_index(drop = True).head(num_top_venues))
    print('\n')
# Out:
# ----Arganzuela----
#               venue  freq
# 0               Bar  0.14
# 1  Tapas Restaurant  0.11
# 2             Plaza  0.07
# 3       Pizza Place  0.07
# 4       Art Gallery  0.07
#
#
# ----Barajas----
#                  venue  freq
# 0  Rental Car Location  0.12
# 1      Airport Service  0.10
# 2     Airport Terminal  0.10
# 3       Duty-free Shop  0.10
# 4                 Café  0.05
#
#
# ----Carabanchel----
#                  venue  freq
# 0        Metro Station  0.67
# 1                Motel  0.33
# 2    Accessories Store  0.00
# 3         Noodle House  0.00
# 4  Monument / Landmark  0.00
#
#
# ----Centro----
#                 venue  freq
# 0               Hotel  0.09
# 1  Spanish Restaurant  0.07
# 2               Plaza  0.06
# 3         Coffee Shop  0.04
# 4                 Bar  0.04
#
#
# ----Chamartín----
#                       venue  freq
# 0        Spanish Restaurant  0.18
# 1                Restaurant  0.12
# 2  Mediterranean Restaurant  0.08
# 3        Seafood Restaurant  0.05
# 4      Gym / Fitness Center  0.05
#
#
# ----Chamberí----
#                 venue  freq
# 0  Spanish Restaurant  0.08
# 1         Supermarket  0.06
# 2          Restaurant  0.05
# 3         Coffee Shop  0.05
# 4                 Bar  0.05
#
#
# ----Ciudad Lineal----
#                        venue  freq
# 0           Tapas Restaurant  0.15
# 1                      Hotel  0.08
# 2                     Bakery  0.08
# 3       Gym / Fitness Center  0.08
# 4  Middle Eastern Restaurant  0.08
#
#
# ----Fuencarral-El Pardo----
#                 venue  freq
# 0          Restaurant  0.06
# 1  Spanish Restaurant  0.05
# 2    Tapas Restaurant  0.05
# 3               Hotel  0.04
# 4        Cocktail Bar  0.04
#
#
# ----Hortaleza----
#                 venue  freq
# 0          Restaurant  0.06
# 1  Spanish Restaurant  0.05
# 2    Tapas Restaurant  0.05
# 3               Hotel  0.04
# 4        Cocktail Bar  0.04
#
#
# ----Latina----
#                  venue  freq
# 0       Scenic Lookout  0.12
# 1  Peruvian Restaurant  0.12
# 2         Soccer Field  0.12
# 3        Train Station  0.12
# 4          Pizza Place  0.12
#
#
# ----Moncloa-Aravaca----
#                 venue  freq
# 0    Tapas Restaurant  0.12
# 1   Paella Restaurant  0.12
# 2  Spanish Restaurant  0.12
# 3                 Bar  0.12
# 4          Restaurant  0.12
#
#
# ----Moratalaz----
#                venue  freq
# 0            Brewery   0.1
# 1         Restaurant   0.1
# 2               Park   0.1
# 3              Plaza   0.1
# 4  Food & Drink Shop   0.1
#
#
# ----Puente de Vallecas----
#             venue  freq
# 0   Grocery Store  0.22
# 1  Scenic Lookout  0.11
# 2            Park  0.11
# 3           Diner  0.11
# 4   Big Box Store  0.11
#
#
# ----Retiro----
#         venue  freq
# 0        Café  0.11
# 1  Restaurant  0.08
# 2      Bakery  0.08
# 3        Park  0.05
# 4   Gastropub  0.05
#
#
# ----Salamanca----
#                 venue  freq
# 0  Spanish Restaurant  0.17
# 1          Restaurant  0.11
# 2               Hotel  0.07
# 3      Clothing Store  0.06
# 4            Boutique  0.05
#
#
# ----San Blas-Canillejas----
#               venue  freq
# 0  Sushi Restaurant  0.08
# 1               Spa  0.08
# 2    Ice Cream Shop  0.08
# 3             Diner  0.08
# 4         Juice Bar  0.08
#
#
# ----Tetuán----
#                 venue  freq
# 0               Hotel  0.09
# 1  Spanish Restaurant  0.07
# 2               Plaza  0.06
# 3         Coffee Shop  0.04
# 4                 Bar  0.04
#
#
# ----Usera----
#                   venue  freq
# 0    Seafood Restaurant  0.12
# 1  Fast Food Restaurant  0.12
# 2     Mobile Phone Shop  0.06
# 3             BBQ Joint  0.06
# 4             Gastropub  0.06
#
#
# ----Vicálvaro----
#                 venue  freq
# 0  Spanish Restaurant  0.17
# 1          Restaurant  0.07
# 2                 Bar  0.07
# 3              Bakery  0.07
# 4               Hotel  0.07
#
#
# ----Villaverde----
#                 venue  freq
# 0   Food & Drink Shop  0.33
# 1  Spanish Restaurant  0.33
# 2   Electronics Store  0.33
# 3   Accessories Store  0.00
# 4           Nightclub  0.00

# %%
#Sort venues in descending order
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
#Create new dataframe to display top 10 venues
num_top_venues = 10
indicators = ['st', 'nd', 'rd']

#Create columns according to number of top venues
columns = ['District']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind + 1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind + 1))

#Create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns = columns)
neighborhoods_venues_sorted['District'] = madrid_grouped['District']

for ind in np.arange(madrid_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(madrid_grouped.iloc[ind, :], num_top_venues)

#Display dataframe with districts and most common venues in every district
neighborhoods_venues_sorted.head()
# Out:
#       District 1st Most Common Venue 2nd Most Common Venue  \
# 0   Arganzuela                   Bar      Tapas Restaurant
# 1      Barajas   Rental Car Location       Airport Service
# 2  Carabanchel         Metro Station                 Motel
# 3       Centro                 Hotel    Spanish Restaurant
# 4    Chamartín    Spanish Restaurant            Restaurant
#
#       3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0                     Plaza           Pizza Place  Gym / Fitness Center
# 1          Airport Terminal        Duty-free Shop          Airport Gate
# 2              Food Service           Flea Market  Fast Food Restaurant
# 3                     Plaza        Ice Cream Shop           Coffee Shop
# 4  Mediterranean Restaurant             Nightclub  Gym / Fitness Center
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0           Art Gallery    Spanish Restaurant                   Gym
# 1        Airport Lounge     Convenience Store         Metro Station
# 2   Embassy / Consulate     Electronics Store        Duty-free Shop
# 3                   Bar    Seafood Restaurant      Tapas Restaurant
# 4    Seafood Restaurant                   Bar            Steakhouse
#
#   9th Most Common Venue 10th Most Common Venue
# 0               Brewery             Restaurant
# 1                  Café      Accessories Store
# 2   Dumpling Restaurant             Donut Shop
# 3           Record Shop     Italian Restaurant
# 4                 Plaza            Pizza Place

# %% [markdown]
# ## Cluster analysis on venues

# %% [markdown]
# #### Initialize Kmeans cluster

# %%
#Initialize number of clusters
kclusters = 5

madrid_grouped_clustering = madrid_grouped.drop('District', 1)

#Run k-means clustering
kmeans = KMeans(n_clusters = kclusters, random_state = 0).fit(madrid_grouped_clustering)

#Check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([2, 2, 3, 2, 2, 2, 2, 2, 2, 2], dtype=int32)

# %% [markdown]
# #### Create new dataframe that includes clusters along with top 10 venues

# %%
#Add cluster labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)
madrid_merged = madrid_data

#Merge to get final data
madrid_merged = madrid_merged.join(neighborhoods_venues_sorted.set_index('District'), on = 'District')

# %%
#Display dataset
madrid_merged
# Out:
#     Zip Code             District Population  Pop Density  \
# 0      28013               Centro    131 928        25234
# 1      28005           Arganzuela    151 965        23516
# 2      28009               Retiro    118 516        21682
# 3      28001            Salamanca    143 800        26667
# 4      28036            Chamartín    143 424        15631
# 5      28013               Tetuán    153 789        28613
# 6      28015             Chamberí    137 401        29364
# 7      28004  Fuencarral-El Pardo    238 756         1004
# 8      28008      Moncloa-Aravaca    116 903         2512
# 9      28047               Latina    233 808         9195
# 10     28025          Carabanchel    243 998        17368
# 11     28026                Usera    134 791        17330
# 12     28038   Puente de Vallecas    227 595        15205
# 13     28030            Moratalaz     94 197        15434
# 14     28027        Ciudad Lineal    212 529        18601
# 15     28004            Hortaleza    180 462         6581
# 16     28021           Villaverde    142 608         7064
# 17     28031    Villa de Vallecas    104 421         1986
# 18     28028            Vicálvaro     70 051         1986
# 19     28022  San Blas-Canillejas    154 357         6924
# 20     28042              Barajas     46 876         1118
#
#                                               Streets  Latitude  Longitude  \
# 0   Palacio , Embajadores , Cortes , Justicia , Un...   40.4190    -3.7118
# 1   Imperial , Acacias , Chopera , Legazpi , Delic...   40.4050    -3.7105
# 2   Pacífico , Adelfas , Estrella , Ibiza , Jeróni...   40.4162    -3.6801
# 3   Recoletos , Goya , Fuente del Berro , Guindale...   40.4262    -3.6851
# 4   El Viso , Prosperidad , Ciudad Jardín , Hispan...   40.4618    -3.6851
# 5   Bellas Vistas , Cuatro Caminos , Castillejos ,...   40.4190    -3.7118
# 6   Gaztambide , Arapiles , Trafalgar , Almagro , ...   40.4305    -3.7105
# 7   El Pardo , Fuentelarreina , Peñagrande , Pilar...   40.4245    -3.6991
# 8   Casa de Campo , Argüelles , Ciudad Universitar...   40.4300    -3.7257
# 9   Los Cármenes , Puerta del Ángel , Lucero , Alu...   40.3961    -3.7486
# 10  Comillas , Opañel , San Isidro , Vista Alegre ...   40.3787    -3.7359
# 11  Orcasitas , Orcasur , San Fermín , Almendrales...   40.3848    -3.7054
# 12  Entrevías , San Diego , Palomeras Bajas , Palo...   40.3966    -3.6547
# 13  Pavones , Horcajo , Marroquina , Media Legua ,...   40.4073    -3.6395
# 14  Ventas , Pueblo Nuevo , Quintana , Concepción ...   40.4427    -3.6446
# 15  Palomas , Piovera , Canillas , Pinar del Rey ,...   40.4245    -3.6991
# 16  Villaverde Alto , San Cristóbal , Butarque , L...   40.3367    -3.6978
# 17  Casco Histórico de Vallecas , Santa Eugenia , ...   40.3809    -3.5863
# 18  Casco Histórico de Vicálvaro , Valdebernardo ,...   40.4319    -3.6649
# 19  Simancas , Hellín , Amposta , Arcos , Rosas , ...   40.4420    -3.5863
# 20  Alameda de Osuna , Aeropuerto , Casco Históric...   40.4679    -3.5711
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0              2.0                 Hotel    Spanish Restaurant
# 1              2.0                   Bar      Tapas Restaurant
# 2              2.0                  Café                Bakery
# 3              2.0    Spanish Restaurant            Restaurant
# 4              2.0    Spanish Restaurant            Restaurant
# 5              2.0                 Hotel    Spanish Restaurant
# 6              2.0    Spanish Restaurant           Supermarket
# 7              2.0            Restaurant    Spanish Restaurant
# 8              2.0     Paella Restaurant      Tapas Restaurant
# 9              2.0        Scenic Lookout      Asian Restaurant
# 10             3.0         Metro Station                 Motel
# 11             1.0  Fast Food Restaurant    Seafood Restaurant
# 12             0.0         Grocery Store                 Diner
# 13             2.0            Restaurant                Bakery
# 14             2.0      Tapas Restaurant  Gym / Fitness Center
# 15             2.0            Restaurant    Spanish Restaurant
# 16             4.0     Food & Drink Shop    Spanish Restaurant
# 17             NaN                   NaN                   NaN
# 18             2.0    Spanish Restaurant                   Bar
# 19             2.0                 Diner     Electronics Store
# 20             2.0   Rental Car Location       Airport Service
#
#        3rd Most Common Venue       4th Most Common Venue  \
# 0                      Plaza              Ice Cream Shop
# 1                      Plaza                 Pizza Place
# 2                 Restaurant                    Fountain
# 3                      Hotel              Clothing Store
# 4   Mediterranean Restaurant                   Nightclub
# 5                      Plaza              Ice Cream Shop
# 6                Coffee Shop                         Bar
# 7           Tapas Restaurant                Cocktail Bar
# 8                        Bar          Spanish Restaurant
# 9        Peruvian Restaurant                 Pizza Place
# 10              Food Service                 Flea Market
# 11         Mobile Phone Shop               Metro Station
# 12             Big Box Store                 Beer Garden
# 13      Gym / Fitness Center               Metro Station
# 14                  Pharmacy                     Brewery
# 15          Tapas Restaurant                Cocktail Bar
# 16         Electronics Store                  Donut Shop
# 17                       NaN                         NaN
# 18                    Bakery                       Hotel
# 19               Coffee Shop  Construction & Landscaping
# 20          Airport Terminal              Duty-free Shop
#
#    5th Most Common Venue      6th Most Common Venue 7th Most Common Venue  \
# 0            Coffee Shop                        Bar    Seafood Restaurant
# 1   Gym / Fitness Center                Art Gallery    Spanish Restaurant
# 2                   Park                  Gastropub           Snack Place
# 3               Boutique     Furniture / Home Store      Tapas Restaurant
# 4   Gym / Fitness Center         Seafood Restaurant                   Bar
# 5            Coffee Shop                        Bar    Seafood Restaurant
# 6             Restaurant           Department Store                 Hotel
# 7                  Hotel                        Bar               Gay Bar
# 8             Restaurant                        Pub         Movie Theater
# 9                  Plaza               Soccer Field     Paella Restaurant
# 10  Fast Food Restaurant        Embassy / Consulate     Electronics Store
# 11       Bubble Tea Shop                        Pub                  Pool
# 12     Electronics Store             Scenic Lookout  Gym / Fitness Center
# 13                  Park          Food & Drink Shop               Brewery
# 14          Food Service  Middle Eastern Restaurant                Bakery
# 15                 Hotel                        Bar               Gay Bar
# 16           Flea Market       Fast Food Restaurant   Embassy / Consulate
# 17                   NaN                        NaN                   NaN
# 18            Restaurant         Chinese Restaurant        Breakfast Spot
# 19        Ice Cream Shop             Clothing Store    Chinese Restaurant
# 20          Airport Gate             Airport Lounge     Convenience Store
#
#    8th Most Common Venue   9th Most Common Venue 10th Most Common Venue
# 0       Tapas Restaurant             Record Shop     Italian Restaurant
# 1                    Gym                 Brewery             Restaurant
# 2     Spanish Restaurant       Paella Restaurant                   Lake
# 3     Italian Restaurant                  Bakery      Accessories Store
# 4             Steakhouse                   Plaza            Pizza Place
# 5       Tapas Restaurant             Record Shop     Italian Restaurant
# 6                Theater        Tapas Restaurant                   Café
# 7     Italian Restaurant               Bookstore         Ice Cream Shop
# 8     Athletics & Sports  Argentinian Restaurant           Cocktail Bar
# 9          Train Station               Gift Shop          Grocery Store
# 10        Duty-free Shop     Dumpling Restaurant             Donut Shop
# 11    Spanish Restaurant                  Bakery              BBQ Joint
# 12                  Park                Creperie           Cupcake Shop
# 13   Fried Chicken Joint                   Plaza     Spanish Restaurant
# 14    Spanish Restaurant              Restaurant     Salon / Barbershop
# 15    Italian Restaurant               Bookstore         Ice Cream Shop
# 16        Duty-free Shop     Dumpling Restaurant            Yoga Studio
# 17                   NaN                     NaN                    NaN
# 18               Brewery                    Pool                   Café
# 19      Sushi Restaurant             Supermarket              Juice Bar
# 20         Metro Station                    Café      Accessories Store

# %% [markdown]
# #### Clean dataset from missing values

# %%
#Remove NAs from dataset
madrid_merged.dropna(axis = 0, how = 'any', thresh = None, subset = None, inplace = True)
madrid_merged
# Out:
#     Zip Code             District Population  Pop Density  \
# 0      28013               Centro    131 928        25234
# 1      28005           Arganzuela    151 965        23516
# 2      28009               Retiro    118 516        21682
# 3      28001            Salamanca    143 800        26667
# 4      28036            Chamartín    143 424        15631
# 5      28013               Tetuán    153 789        28613
# 6      28015             Chamberí    137 401        29364
# 7      28004  Fuencarral-El Pardo    238 756         1004
# 8      28008      Moncloa-Aravaca    116 903         2512
# 9      28047               Latina    233 808         9195
# 10     28025          Carabanchel    243 998        17368
# 11     28026                Usera    134 791        17330
# 12     28038   Puente de Vallecas    227 595        15205
# 13     28030            Moratalaz     94 197        15434
# 14     28027        Ciudad Lineal    212 529        18601
# 15     28004            Hortaleza    180 462         6581
# 16     28021           Villaverde    142 608         7064
# 18     28028            Vicálvaro     70 051         1986
# 19     28022  San Blas-Canillejas    154 357         6924
# 20     28042              Barajas     46 876         1118
#
#                                               Streets  Latitude  Longitude  \
# 0   Palacio , Embajadores , Cortes , Justicia , Un...   40.4190    -3.7118
# 1   Imperial , Acacias , Chopera , Legazpi , Delic...   40.4050    -3.7105
# 2   Pacífico , Adelfas , Estrella , Ibiza , Jeróni...   40.4162    -3.6801
# 3   Recoletos , Goya , Fuente del Berro , Guindale...   40.4262    -3.6851
# 4   El Viso , Prosperidad , Ciudad Jardín , Hispan...   40.4618    -3.6851
# 5   Bellas Vistas , Cuatro Caminos , Castillejos ,...   40.4190    -3.7118
# 6   Gaztambide , Arapiles , Trafalgar , Almagro , ...   40.4305    -3.7105
# 7   El Pardo , Fuentelarreina , Peñagrande , Pilar...   40.4245    -3.6991
# 8   Casa de Campo , Argüelles , Ciudad Universitar...   40.4300    -3.7257
# 9   Los Cármenes , Puerta del Ángel , Lucero , Alu...   40.3961    -3.7486
# 10  Comillas , Opañel , San Isidro , Vista Alegre ...   40.3787    -3.7359
# 11  Orcasitas , Orcasur , San Fermín , Almendrales...   40.3848    -3.7054
# 12  Entrevías , San Diego , Palomeras Bajas , Palo...   40.3966    -3.6547
# 13  Pavones , Horcajo , Marroquina , Media Legua ,...   40.4073    -3.6395
# 14  Ventas , Pueblo Nuevo , Quintana , Concepción ...   40.4427    -3.6446
# 15  Palomas , Piovera , Canillas , Pinar del Rey ,...   40.4245    -3.6991
# 16  Villaverde Alto , San Cristóbal , Butarque , L...   40.3367    -3.6978
# 18  Casco Histórico de Vicálvaro , Valdebernardo ,...   40.4319    -3.6649
# 19  Simancas , Hellín , Amposta , Arcos , Rosas , ...   40.4420    -3.5863
# 20  Alameda de Osuna , Aeropuerto , Casco Históric...   40.4679    -3.5711
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0              2.0                 Hotel    Spanish Restaurant
# 1              2.0                   Bar      Tapas Restaurant
# 2              2.0                  Café                Bakery
# 3              2.0    Spanish Restaurant            Restaurant
# 4              2.0    Spanish Restaurant            Restaurant
# 5              2.0                 Hotel    Spanish Restaurant
# 6              2.0    Spanish Restaurant           Supermarket
# 7              2.0            Restaurant    Spanish Restaurant
# 8              2.0     Paella Restaurant      Tapas Restaurant
# 9              2.0        Scenic Lookout      Asian Restaurant
# 10             3.0         Metro Station                 Motel
# 11             1.0  Fast Food Restaurant    Seafood Restaurant
# 12             0.0         Grocery Store                 Diner
# 13             2.0            Restaurant                Bakery
# 14             2.0      Tapas Restaurant  Gym / Fitness Center
# 15             2.0            Restaurant    Spanish Restaurant
# 16             4.0     Food & Drink Shop    Spanish Restaurant
# 18             2.0    Spanish Restaurant                   Bar
# 19             2.0                 Diner     Electronics Store
# 20             2.0   Rental Car Location       Airport Service
#
#        3rd Most Common Venue       4th Most Common Venue  \
# 0                      Plaza              Ice Cream Shop
# 1                      Plaza                 Pizza Place
# 2                 Restaurant                    Fountain
# 3                      Hotel              Clothing Store
# 4   Mediterranean Restaurant                   Nightclub
# 5                      Plaza              Ice Cream Shop
# 6                Coffee Shop                         Bar
# 7           Tapas Restaurant                Cocktail Bar
# 8                        Bar          Spanish Restaurant
# 9        Peruvian Restaurant                 Pizza Place
# 10              Food Service                 Flea Market
# 11         Mobile Phone Shop               Metro Station
# 12             Big Box Store                 Beer Garden
# 13      Gym / Fitness Center               Metro Station
# 14                  Pharmacy                     Brewery
# 15          Tapas Restaurant                Cocktail Bar
# 16         Electronics Store                  Donut Shop
# 18                    Bakery                       Hotel
# 19               Coffee Shop  Construction & Landscaping
# 20          Airport Terminal              Duty-free Shop
#
#    5th Most Common Venue      6th Most Common Venue 7th Most Common Venue  \
# 0            Coffee Shop                        Bar    Seafood Restaurant
# 1   Gym / Fitness Center                Art Gallery    Spanish Restaurant
# 2                   Park                  Gastropub           Snack Place
# 3               Boutique     Furniture / Home Store      Tapas Restaurant
# 4   Gym / Fitness Center         Seafood Restaurant                   Bar
# 5            Coffee Shop                        Bar    Seafood Restaurant
# 6             Restaurant           Department Store                 Hotel
# 7                  Hotel                        Bar               Gay Bar
# 8             Restaurant                        Pub         Movie Theater
# 9                  Plaza               Soccer Field     Paella Restaurant
# 10  Fast Food Restaurant        Embassy / Consulate     Electronics Store
# 11       Bubble Tea Shop                        Pub                  Pool
# 12     Electronics Store             Scenic Lookout  Gym / Fitness Center
# 13                  Park          Food & Drink Shop               Brewery
# 14          Food Service  Middle Eastern Restaurant                Bakery
# 15                 Hotel                        Bar               Gay Bar
# 16           Flea Market       Fast Food Restaurant   Embassy / Consulate
# 18            Restaurant         Chinese Restaurant        Breakfast Spot
# 19        Ice Cream Shop             Clothing Store    Chinese Restaurant
# 20          Airport Gate             Airport Lounge     Convenience Store
#
#    8th Most Common Venue   9th Most Common Venue 10th Most Common Venue
# 0       Tapas Restaurant             Record Shop     Italian Restaurant
# 1                    Gym                 Brewery             Restaurant
# 2     Spanish Restaurant       Paella Restaurant                   Lake
# 3     Italian Restaurant                  Bakery      Accessories Store
# 4             Steakhouse                   Plaza            Pizza Place
# 5       Tapas Restaurant             Record Shop     Italian Restaurant
# 6                Theater        Tapas Restaurant                   Café
# 7     Italian Restaurant               Bookstore         Ice Cream Shop
# 8     Athletics & Sports  Argentinian Restaurant           Cocktail Bar
# 9          Train Station               Gift Shop          Grocery Store
# 10        Duty-free Shop     Dumpling Restaurant             Donut Shop
# 11    Spanish Restaurant                  Bakery              BBQ Joint
# 12                  Park                Creperie           Cupcake Shop
# 13   Fried Chicken Joint                   Plaza     Spanish Restaurant
# 14    Spanish Restaurant              Restaurant     Salon / Barbershop
# 15    Italian Restaurant               Bookstore         Ice Cream Shop
# 16        Duty-free Shop     Dumpling Restaurant            Yoga Studio
# 18               Brewery                    Pool                   Café
# 19      Sushi Restaurant             Supermarket              Juice Bar
# 20         Metro Station                    Café      Accessories Store

# %% [markdown]
# #### Visualize results

# %%
#Create map
map_clusters = folium.Map(location = [Latitude, Longitude], zoom_start = 11)

#Set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

#Add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(madrid_merged['Latitude'], madrid_merged['Longitude'], madrid_merged['District'], madrid_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html = True)
    folium.CircleMarker(
        [lat, lon],
        radius = 5,
        popup = label,
        color = rainbow[int(cluster)-1],
        fill = True,
        fill_color = rainbow[int(cluster)-1],
        fill_opacity = 0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Examine cluster results

# %%
#Cluster 0
madrid_merged.loc[madrid_merged['Cluster Labels'] == 0, madrid_merged.columns[[1] + list(range(5, madrid_merged.shape[1]))]]
# Out:
#               District  Latitude  Longitude  Cluster Labels  \
# 12  Puente de Vallecas   40.3966    -3.6547             0.0
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 12         Grocery Store                 Diner         Big Box Store
#
#    4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 12           Beer Garden     Electronics Store        Scenic Lookout
#
#    7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 12  Gym / Fitness Center                  Park              Creperie
#
#    10th Most Common Venue
# 12           Cupcake Shop

# %%
#Cluster 1
madrid_merged.loc[madrid_merged['Cluster Labels'] == 1, madrid_merged.columns[[1] + list(range(5, madrid_merged.shape[1]))]]
# Out:
#    District  Latitude  Longitude  Cluster Labels 1st Most Common Venue  \
# 11    Usera   40.3848    -3.7054             1.0  Fast Food Restaurant
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 11    Seafood Restaurant     Mobile Phone Shop         Metro Station
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 11       Bubble Tea Shop                   Pub                  Pool
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 11    Spanish Restaurant                Bakery              BBQ Joint

# %%
#Cluster 2
madrid_merged.loc[madrid_merged['Cluster Labels'] == 2, madrid_merged.columns[[1] + list(range(5, madrid_merged.shape[1]))]]
# Out:
#                District  Latitude  Longitude  Cluster Labels  \
# 0                Centro   40.4190    -3.7118             2.0
# 1            Arganzuela   40.4050    -3.7105             2.0
# 2                Retiro   40.4162    -3.6801             2.0
# 3             Salamanca   40.4262    -3.6851             2.0
# 4             Chamartín   40.4618    -3.6851             2.0
# 5                Tetuán   40.4190    -3.7118             2.0
# 6              Chamberí   40.4305    -3.7105             2.0
# 7   Fuencarral-El Pardo   40.4245    -3.6991             2.0
# 8       Moncloa-Aravaca   40.4300    -3.7257             2.0
# 9                Latina   40.3961    -3.7486             2.0
# 13            Moratalaz   40.4073    -3.6395             2.0
# 14        Ciudad Lineal   40.4427    -3.6446             2.0
# 15            Hortaleza   40.4245    -3.6991             2.0
# 18            Vicálvaro   40.4319    -3.6649             2.0
# 19  San Blas-Canillejas   40.4420    -3.5863             2.0
# 20              Barajas   40.4679    -3.5711             2.0
#
#    1st Most Common Venue 2nd Most Common Venue     3rd Most Common Venue  \
# 0                  Hotel    Spanish Restaurant                     Plaza
# 1                    Bar      Tapas Restaurant                     Plaza
# 2                   Café                Bakery                Restaurant
# 3     Spanish Restaurant            Restaurant                     Hotel
# 4     Spanish Restaurant            Restaurant  Mediterranean Restaurant
# 5                  Hotel    Spanish Restaurant                     Plaza
# 6     Spanish Restaurant           Supermarket               Coffee Shop
# 7             Restaurant    Spanish Restaurant          Tapas Restaurant
# 8      Paella Restaurant      Tapas Restaurant                       Bar
# 9         Scenic Lookout      Asian Restaurant       Peruvian Restaurant
# 13            Restaurant                Bakery      Gym / Fitness Center
# 14      Tapas Restaurant  Gym / Fitness Center                  Pharmacy
# 15            Restaurant    Spanish Restaurant          Tapas Restaurant
# 18    Spanish Restaurant                   Bar                    Bakery
# 19                 Diner     Electronics Store               Coffee Shop
# 20   Rental Car Location       Airport Service          Airport Terminal
#
#          4th Most Common Venue 5th Most Common Venue  \
# 0               Ice Cream Shop           Coffee Shop
# 1                  Pizza Place  Gym / Fitness Center
# 2                     Fountain                  Park
# 3               Clothing Store              Boutique
# 4                    Nightclub  Gym / Fitness Center
# 5               Ice Cream Shop           Coffee Shop
# 6                          Bar            Restaurant
# 7                 Cocktail Bar                 Hotel
# 8           Spanish Restaurant            Restaurant
# 9                  Pizza Place                 Plaza
# 13               Metro Station                  Park
# 14                     Brewery          Food Service
# 15                Cocktail Bar                 Hotel
# 18                       Hotel            Restaurant
# 19  Construction & Landscaping        Ice Cream Shop
# 20              Duty-free Shop          Airport Gate
#
#         6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0                         Bar    Seafood Restaurant      Tapas Restaurant
# 1                 Art Gallery    Spanish Restaurant                   Gym
# 2                   Gastropub           Snack Place    Spanish Restaurant
# 3      Furniture / Home Store      Tapas Restaurant    Italian Restaurant
# 4          Seafood Restaurant                   Bar            Steakhouse
# 5                         Bar    Seafood Restaurant      Tapas Restaurant
# 6            Department Store                 Hotel               Theater
# 7                         Bar               Gay Bar    Italian Restaurant
# 8                         Pub         Movie Theater    Athletics & Sports
# 9                Soccer Field     Paella Restaurant         Train Station
# 13          Food & Drink Shop               Brewery   Fried Chicken Joint
# 14  Middle Eastern Restaurant                Bakery    Spanish Restaurant
# 15                        Bar               Gay Bar    Italian Restaurant
# 18         Chinese Restaurant        Breakfast Spot               Brewery
# 19             Clothing Store    Chinese Restaurant      Sushi Restaurant
# 20             Airport Lounge     Convenience Store         Metro Station
#
#      9th Most Common Venue 10th Most Common Venue
# 0              Record Shop     Italian Restaurant
# 1                  Brewery             Restaurant
# 2        Paella Restaurant                   Lake
# 3                   Bakery      Accessories Store
# 4                    Plaza            Pizza Place
# 5              Record Shop     Italian Restaurant
# 6         Tapas Restaurant                   Café
# 7                Bookstore         Ice Cream Shop
# 8   Argentinian Restaurant           Cocktail Bar
# 9                Gift Shop          Grocery Store
# 13                   Plaza     Spanish Restaurant
# 14              Restaurant     Salon / Barbershop
# 15               Bookstore         Ice Cream Shop
# 18                    Pool                   Café
# 19             Supermarket              Juice Bar
# 20                    Café      Accessories Store

# %%
#Cluster 3
madrid_merged.loc[madrid_merged['Cluster Labels'] == 3, madrid_merged.columns[[1] + list(range(5, madrid_merged.shape[1]))]]
# Out:
#        District  Latitude  Longitude  Cluster Labels 1st Most Common Venue  \
# 10  Carabanchel   40.3787    -3.7359             3.0         Metro Station
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 10                 Motel          Food Service           Flea Market
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 10  Fast Food Restaurant   Embassy / Consulate     Electronics Store
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 10        Duty-free Shop   Dumpling Restaurant             Donut Shop

# %%
#Cluster 4
madrid_merged.loc[madrid_merged['Cluster Labels'] == 4, madrid_merged.columns[[1] + list(range(5, madrid_merged.shape[1]))]]
# Out:
#       District  Latitude  Longitude  Cluster Labels 1st Most Common Venue  \
# 16  Villaverde   40.3367    -3.6978             4.0     Food & Drink Shop
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 16    Spanish Restaurant     Electronics Store            Donut Shop
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 16           Flea Market  Fast Food Restaurant   Embassy / Consulate
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 16        Duty-free Shop   Dumpling Restaurant            Yoga Studio
